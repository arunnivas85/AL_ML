# %% [markdown]
# <a href="https://colab.research.google.com/github/arunnivas85/AL_ML/blob/main/Revision_Pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("This is Pandas Test")
# Out:
# This is Pandas Test

# %%
import pandas as pd
df=pd.DataFrame(
    {
        "name" : ["Arun","Nishanth","Dhaksin","jeyanthi"],
        "age"  : [40,12,2,45],
        "score": [70, 10 ,80,40]
    }
)
print(df)
# Out:
#        name  age  score
# 0      Arun   40     70
# 1  Nishanth   12     10
# 2   Dhaksin    2     80
# 3  jeyanthi   45     40

# %%
from contextlib import nullcontext
# df.head(2)
# df.tail(2)
# df.info()
# df.describe()
# df.dtypes
# df.shape
# df.isnull().sum()

# df.loc[0]
# df.loc[0:1, "name":"age"]   #Range based on arrangement  + Includes End + Label Based

# df.iloc[0]
# df.iloc[0:1, 1:2]   #Range based on arrangement  + Excludes End + Position Based

# df["age"]>40   # Return only Boolean
df[(df["age"]>30)  & (df["score"] > 50) ]   # Return records
# Out:
#    name  age  score
# 0  Arun   40     70
